# %% [markdown]
# # Baby Cry Classification using Machine Learning Algorithms

# %% [markdown]
# **Author**: Jing Chen and Shruti Biradar

# %% [markdown]
# ## Project Overview - purpose and our solution

# %% [markdown]
# **Project Goal**: In the first phase of our research, we aim to classify baby cry based on demographic features of babies and the acoustic cry signals using machine learning techniques and then compare the performance of the different machine learning methods based on the F1 Score metric.

# %% [markdown]
# **Inputs**:
# *   Audio files in .wav format including file name
# *   Acoustic features extracted from audio waves of baby cries, such as Mel-frequency cepstral coefficients and chroma features
# *   Demographic features of babies such as age and gender

# %% [markdown]
# **Outputs**: Labels of cry reasons:
# *   belly pain
# *   burping
# *   discomfort
# *   hunger
# *   tiredness

# %% [markdown]
# ### Structure of Code
#
#         I. Install and Import Packages
#
#         II. Load Dataset- audio files
#
#         III. Exploratory Data Analysis
#
#         IV. Pre-processing and Feature Extraction
#
#         V. Build Classifier
#
#         VI. Run all models and Report Performance

# %% [markdown]
# ## I. Install and Import packages

# %%
# load required packages
# !pip install pydub

import wave
import math
import os
import matplotlib.pyplot as plt
import librosa
import librosa.display
import wave
import pandas as pd
import numpy as np
import pydub
from scipy.io.wavfile import read
from pydub import AudioSegment
from pydub.utils import make_chunks
from os import walk
from os import listdir
from os.path import isfile, join
import random
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from statistics import mean
from matplotlib import pyplot
from sklearn.model_selection import train_test_split,cross_validate,RepeatedStratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score,precision_recall_fscore_support
from sklearn.metrics import ConfusionMatrixDisplay, multilabel_confusion_matrix
from sklearn.preprocessing import MinMaxScaler,StandardScaler,normalize,LabelEncoder
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV,StratifiedKFold,GridSearchCV
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from numpy.linalg import eigh
from sklearn.svm import SVC
import numpy as np
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics
from keras.callbacks import ModelCheckpoint
from datetime import datetime
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from datetime import datetime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)

# %% [markdown]
# ## II. Load Dataset- audio files

# %% [markdown]
# We use Donate-A-Cry corpus dataset, which consists of 457 unique child cry audio files along with tags for babies’ demographic information (age and gender) and cry reasons (such as hungry, belly pain, discomfort, burping, and tiredness).

# %%
# mount google drive to access files and folders
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# load the data
audiopath_df = pd.DataFrame(columns=['file','audio_class'])
cwd = os.getcwd()
folder = ['belly_pain', 'burping','discomfort','hungry','tired']
for t in folder:
  folder_path = cwd+'/gdrive/MyDrive/DS5500/audio/'+t
  audiofile_path = [folder_path+'/'+file for file in os.listdir(folder_path) if file.endswith('.wav')]
  file_df=pd.DataFrame({'file':audiofile_path,
                  'audio_class':t})
  audiopath_df = pd.concat([audiopath_df, file_df],ignore_index=True)

# %%
# a snippet of the dataframe
audiopath_df.head(6)
# Out:
#                                                 file audio_class
# 0  /content/gdrive/MyDrive/DS5500/audio/belly_pai...  belly_pain
# 1  /content/gdrive/MyDrive/DS5500/audio/belly_pai...  belly_pain
# 2  /content/gdrive/MyDrive/DS5500/audio/belly_pai...  belly_pain
# 3  /content/gdrive/MyDrive/DS5500/audio/belly_pai...  belly_pain
# 4  /content/gdrive/MyDrive/DS5500/audio/belly_pai...  belly_pain
# 5  /content/gdrive/MyDrive/DS5500/audio/belly_pai...  belly_pain

# %% [markdown]
# ## III. Exploratory Data Analysis

# %%
# extract length of file, age and gender of babies from the files and append to the dataframe

def calculate_audio_length(file_path):
    # load audio file using file path and calculate the length of audio in minutes
    y,sr = librosa.load(file_path)
    length = len(y)/sr
    return length

def extract_gender(file_path):
    # extract information on gender from file name
    g = file_path.split("-")[-3]
    if g == "m":
        return "Male"
    else: return "Female"

def extract_age(file_path):
    # extract information on age in month from file name
    a = int(file_path.split("-")[-2])
    return a

# %%
audiopath_df["length"] = audiopath_df["file"].map(lambda x:calculate_audio_length(x))
audiopath_df["gender"] = audiopath_df["file"].map(lambda x:extract_gender(x))
audiopath_df["age_in_months"] = audiopath_df["file"].map(lambda x:extract_age(x))

# %% [markdown]
# ## IV. Feature Extraction and Dimentionality Reduction

# %% [markdown]
# **(1)** Framing:  For an audio file, the waveform is cut into segments with a duration of 1-second

# %% [markdown]
# **(2)** Feature Extraction

# %% [markdown]
# | Acoustic Feature | Definition | Number of Features Extracted per Frame |
# | :-: |:-- | :-: |
# | Mel-frequency cepstral coefficients (MFCC)| A set of features derived from log short-term power spectrum of a sound signal  on a nonlinear mel scale of frequency| 39 |
# | Spectral Centroid| A number that represents the amplitude at the center of the spectrum of the signal distribution over a window calculated from the Fourier transform frequency.  $$
#    Spectral\space Centroid = \frac{\sum\limits_{n=0}^{N-1} f(n)x(n)}{\sum\limits_{n=0}^{N-1} x(n)}
# $$ <br> where x(n) is the weighted frequency value of nth bin, and f(n) is the center frequency of nth bin.| 1 |
# | Spectral Flatness| A measure that quantifies how much a sound resembles a pure tone rather than noise <br> <br> $${{Spectral\space Flatness}}={\frac  {\exp \left({\frac  {1}{N}}\sum _{{n=0}}^{{N-1}}\ln x(n)\right)}{{\frac  {1}{N}}\sum _{{n=0}}^{{N-1}}x(n)}}$$ <br> where x(n) represents the magnitude of nth bin.| 1 |
# | Spectral Contrast| The decibel difference between peaks and valleys in the spectrum| 7  |
# | Spectral Rolloff| The frequency below which 85% of the magnitude distribution is concentrated | 1  |
# | Chroma Features| A set of features represent the tonal content of a musical audio signal in a condensed form. | 12 |

# %% [markdown]
# **(3)** Flattening Features: Each 2-D acoustic feature is converted into 1-d vector before passing as input in the next process by flattening.

# %% [markdown]
# **(4)** Dimentionality Reduction and Standardization: We are using use standardization as our scaling method to have data centered around the mean with unit std. deviation in each column and we also do PCA for reducing some 1000+ features to key features that captures most of the information about the data.

# %%
# function for feature extraction

from numpy.lib.shape_base import row_stack
def processing_audio(audio_df = audiopath_df.head(), n_second = 1):
    cry_reason = []
    mfccs = []
    for idx, row in enumerate(audio_df['file']):
      print(row)
      y, s = librosa.load(row)
      cry_reason.append(audio_df['audio_class'][idx])
      # Start from dividing the sound signal into the form of frames with a duration of 6-seconds
      f1 = y[len(y)-6*s:]
      print(len(f1))
      # Extract Mel-frequency cepstral coefficients (MFCCs) to represent the short-term power spectrum of sound.
      mfcc = librosa.feature.mfcc(y=f1, sr=s, n_mfcc=39)
      mfccs.append(mfcc)
    output_df = pd.DataFrame({
                              "cry_reason" : cry_reason,
                              "mfcc" : mfccs
                              })
    return output_df

# %%
def convert_matrix_vector_to_df(matrix_vector):
    # convert a vector of matrix to a vector of arrays by flattening all nested arrays
    flatten_df = matrix_vector.flatten()
    return flatten_df

# %%
def convert_matrix_to_columns(data, column_name):
    # if the first cell of the column is a matrix then convert this column into multiple columns by flattening the matrix
    df = data[column_name].map(lambda x:convert_matrix_vector_to_df(x))
    temp_df = pd.DataFrame(df.tolist(),index = df.index)
    temp_df.columns = [column_name + f'{c}' for c in temp_df.columns]
    data = pd.concat([data,temp_df],axis =1)
    data = data.drop([column_name], axis=1)
    return data

# %%
def feature_extraction(file_path_df):
    data_df = processing_audio(audio_df = audiopath_df, n_second = 1)
    return data_df

# %% [markdown]
# ## V. Build Classifiers

# %% [markdown]
# #### Convolution Neural Network (CNN)

# %%
# model architecture

from keras.engine.base_layer import regularizers
def cnn_structure(x_train,x_test,num_labels=5):
  #parametrs for input into the model
  num_rows = 39 #corresponds to height of an image
  num_columns = 259 #corresponds to width of an image
  num_channels = 1 #channels in an image, 1 suggests its a grayscale image

  #reshape our input data to match the

  #x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
  #x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
  print(x_train.shape)

  # Construct model
  model = Sequential()

  # Add convolution layers
  model.add(Conv2D(32,(3,3), input_shape=(num_rows, num_columns, num_channels), activation='relu', kernel_regularizer= regularizers.l2(0.01)))
  #model.add(Conv2D(32,(3,3), input_shape=(num_rows, num_columns, num_channels), activation='relu'))
  model.add(MaxPooling2D(2,2))
  #model.add(Dropout(0.4))

  model.add(Conv2D(64,(3,3), activation='relu',kernel_regularizer= regularizers.l2(0.01)))
  #model.add(Conv2D(64,(3,3), activation='relu'))
  model.add(MaxPooling2D(2,2))
  #model.add(Dropout(0.4))

  model.add(Conv2D(128,(3,3), activation='relu',kernel_regularizer= regularizers.l2(0.01)))
  #model.add(Conv2D(128,(3,3), activation='relu'))
  model.add(MaxPooling2D(2,2))
  #model.add(Dropout(0.4))

  # output feature map to flattened vector
  model.add(Flatten())

  # Add fully connected layers
  model.add(Dense(64, activation='relu'))
  #model.add(Dropout(0.2))
  model.add(Dense(5, activation='softmax'))

  return model

# %%
#Train the model
def cnn_model(x_train,x_test,y_train, y_test, x_val, y_val):

  print('in model')
  #convert the mfcc and label columns to arrays
  X_train = np.array(x_train.tolist())
  y_train = np.array(y_train.tolist())
  X_test = np.array(x_test.tolist())
  y_test = np.array(y_test.tolist())
  X_val = np.array(x_val.tolist())
  y_val = np.array(y_val.tolist())

  print(X_train.shape)

  # label encoding
  le = LabelEncoder()
  y_train = to_categorical(le.fit_transform(y_train))
  y_test = to_categorical(le.transform(y_test))
  y_val = to_categorical(le.transform(y_val))
  print('le done')

  #build model architecture
  model = cnn_structure(X_train,X_test,5)

  model.summary()

  print('starting compile')
  # Compile the model
  model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['categorical_accuracy'])

  num_epochs = 100
  num_batch_size = 128

  # save the best training weights
  model_callback_checkpoint = ModelCheckpoint(filepath='cnn_model/bestmodel.h5',save_best_only=True, monitor='val_loss')
  history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_val, y_val), callbacks=[model_callback_checkpoint])

  # load the saved model
  new_model = load_model('cnn_model/bestmodel.h5')

  # get model predictions on test data
  predictions = new_model.predict(X_test)

  # since the have our predictions in binary matrix we get the index of the highest prob value
  y_pred = np.argmax(predictions, axis = 1)

  # we apply inverse of label encoder to get the corresponding lables of the numeric values
  y_pred_labels = le.inverse_transform(y_pred)

  return history, y_pred_labels

# %% [markdown]
# ## VII. Report Performance

# %%
def report_performance(y_test,y_pred):
    # calculate precision, recall, and f1 based on the cry reason of orginal audio and predictions
    precision_1, recall_1,f1_1, null_value_1 = precision_recall_fscore_support(y_test, y_pred, average='macro', zero_division=0)

    precision_2, recall_2,f1_2, null_value_2 = precision_recall_fscore_support(y_test, y_pred, average='weighted', zero_division=0)
    # calucate accuracy rate
    accuracy = accuracy_score(y_test,y_pred)
    return {
        'precision_macro': precision_1,
        'recall_macro': recall_1,
        'f1_macro': f1_1,
        'precision_weighted': precision_2,
        'recall_weighted': recall_2,
        'f1_weighted': f1_2,
        'accuracy': accuracy
    }

# %%
### Feature Extraction
data_df = feature_extraction(audiopath_df)
# Out:
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/d6cda191-4962-4308-9a36-46d5648a95ed-1431159272600-1.7-m-04-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/69BDA5D6-0276-4462-9BF7-951799563728-1436936185-1.1-m-26-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138495-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138524-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/d6cda191-4962-4308-9a36-46d5648a95ed-1431159262344-1.7-m-04-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138591-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/549a46d8-9c84-430e-ade8-97eae2bef787-1430130772174-1.7-m-48-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138647-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/C421C6FE-DFEE-4080-8AEA-848E7CE4756B-1430548333-1.0-f-26-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138536-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138514-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/d6cda191-4962-4308-9a36-46d5648a95ed-1431700390946-1.7-m-04-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/ae5f103b-5fee-442f-bb1b-d9d0570c46ab-1431533857965-1.7-m-26-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138545-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/999bf14b-e417-4b44-b746-9253f81efe38-1430974001343-1.7-m-26-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/belly_pain/643D64AD-B711-469A-AF69-55C0D5D3E30F-1430138506-1.0-m-72-bp.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/af30880e-5f98-4dc0-b37a-be6b21fa0ba3-1431240072536-1.7-m-26-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/7E4B9C14-F955-4BED-9B03-7F3096A6CBFF-1430540826-1.0-f-26-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/7E4B9C14-F955-4BED-9B03-7F3096A6CBFF-1430232208-1.0-f-26-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/7A864194-4B6B-4850-ABBF-0C2A8170107B-1436846915-1.1-f-26-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/F24DE44B-762C-4149-AC92-96A5E57ED118-1430816949-1.0-m-04-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/5afc6a14-a9d8-45f8-b31d-c79dd87cc8c6-1430757039803-1.7-m-48-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/AEA8AE04-D00E-48A7-8A0B-6D87E2175121-1430563241-1.0-f-72-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/burping/79FF400A-97E2-4701-987D-C7C850D5523C-1430089648-1.0-f-48-bu.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/discomfort/64acb345-a61e-4ef3-a5a6-cf83c04b83f1-1430058990597-1.7-m-72-dc.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/discomfort/2294E2B2-8E36-4DA6-A898-B947CB9446AB-1436462707-1.1-m-26-dc.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/discomfort/64acb345-a61e-4ef3-a5a6-cf83c04b83f1-1430059012473-1.7-m-72-dc.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/discomfort/665BDF6D-2897-49F9-8AD0-978B3B2A0468-1430530218-1.0-m-26-dc.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/discomfort
ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/C421C6FE-DFEE-4080-8AEA-848E7CE4756B-1430548393-1.0-f-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/d6cda191-4962-4308-9a36-46d5648a95ed-1431587887997-1.7-m-04-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/cecd525b-18fd-49e3-b2b9-dfb08b93ad95-1430110029205-1.7-m-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/7A22229D-06C2-4AAA-9674-DE5DF1906B3A-1436891957-1.1-m-72-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/ca7d8d54-13cb-4060-8db4-90651b60c078-1434674792223-1.7-f-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/eea17285-4ab9-4d34-a2f5-55fc8c866ac6-1431887695278-1.7-f-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/06c4cfa2-7fa6-4fda-91a1-ea186a4acc64-1430029237378-1.7-f-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/C5127741-5897-468C-A543-7F1B72569F0E-1428333964-1.0-m-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/d6cda191-4962-4308-9a36-46d5648a95ed-1431616581736-1.7-m-04-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/D4665929-8695-4655-927F-63F09B2D4CB8-1430726940-1.0-f-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/d6cda191-4962-4308-9a36-46d5648a95ed-1431587899682-1.7-m-04-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/06c4cfa2-7fa6-4fda-91a1-ea186a4acc64-1430029221058-1.7-f-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/1309B82C-F146-46F0-A723-45345AFA6EA8-1431172241-1.0-f-48-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/7A22229D-06C2-4AAA-9674-DE5DF1906B3A-1436891944-1.1-m-72-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/03ADDCFB-354E-416D-BF32-260CF47F7060-1433658024-1.1-f-04-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/d5abedab-9ed5-48d0-a83b-fc00c33d6d6b-1430079192907-1.7-f-04-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/B2AABCE0-1F62-4B57-B58A-308959ABDFE7-1437188766-1.1-m-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/b4c460d8-bd6b-4017-9bb8-2ae4ff0c5af1-1430418266487-1.7-f-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/B2AABCE0-1F62-4B57-B58A-308959ABDFE7-1437188751-1.1-m-26-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/79FF400A-97E2-4701-987D-C7C850D5523C-1430089487-1.0-f-48-ti.wav
# 132300
# /content/gdrive/MyDrive/DS5500/audio/tired/C421C6FE-DFEE-4080-8AEA-848E7CE4756B-1430548384-1.0-m-26-ti.wav
# 132300

# %%
# prep the data for input

y = data_df['cry_reason']
X = data_df['mfcc']

print(X.shape)
print(y.shape)
# Out:
# (457,)
# (457,)

# %%
# train-test-val split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.20, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (292,)
# (92,)
# (73,)

# %%
history, y_pred = cnn_model(X_train, X_test, y_train, y_test, X_val, y_val)

# summarize training and val accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy over epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize training and val loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss over epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# calculate performance metrics
metrics_dict = report_performance(y_test,y_pred)
metrics_df = pd.Series(metrics_dict).to_frame().T

metrics_df
# Out:
# in model
# (292, 39, 259)
# le done
# (292, 39, 259)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 37, 257, 32)       320
#
#  max_pooling2d_9 (MaxPooling  (None, 18, 128, 32)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 126, 64)       18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 63, 64)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 6, 61, 128)        73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 3, 30, 128)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 11520)             0
#
#  dense_6 (Dense)             (None, 64)                737344
#
#  dense_7 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 830,341
# Trainable params: 830,341
# Non-trainable params: 0
# _________________________________________________________________
# starting compile
# Epoch 1/100
# 3/3 [==============================] - 2s 165ms/step - loss: 11.1697 - categorical_accuracy: 0.5651 - val_loss: 32.0572 - val_categorical_accuracy: 0.0959
# Epoch 2/100
# 3/3 [==============================] - 0s 66ms/step - loss: 17.7670 - categorical_accuracy: 0.5240 - val_loss: 6.9926 - val_categorical_accuracy: 0.7945
# Epoch 3/100
# 3/3 [==============================] - 0s 63ms/step - loss: 4.2037 - categorical_accuracy: 0.8596 - val_loss: 4.0741 - val_categorical_accuracy: 0.7945
# Epoch 4/100
# 3/3 [==============================] - 0s 60ms/step - loss: 2.5775 - categorical_accuracy: 0.8630 - val_loss: 2.4796 - val_categorical_accuracy: 0.7945
# Epoch 5/100
# 3/3 [==============================] - 0s 59ms/step - loss: 2.0379 - categorical_accuracy: 0.8562 - val_loss: 2.3855 - val_categorical_accuracy: 0.7945
# Epoch 6/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.9236 - categorical_accuracy: 0.8630 - val_loss: 2.0813 - val_categorical_accuracy: 0.7945
# Epoch 7/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.8770 - categorical_accuracy: 0.8630 - val_loss: 2.0927 - val_categorical_accuracy: 0.7945
# Epoch 8/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.7963 - categorical_accuracy: 0.8630 - val_loss: 2.2950 - val_categorical_accuracy: 0.7945
# Epoch 9/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.8244 - categorical_accuracy: 0.8630 - val_loss: 2.1336 - val_categorical_accuracy: 0.7945
# Epoch 10/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.7551 - categorical_accuracy: 0.8630 - val_loss: 2.1067 - val_categorical_accuracy: 0.7945
# Epoch 11/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.7240 - categorical_accuracy: 0.8630 - val_loss: 2.0974 - val_categorical_accuracy: 0.7945
# Epoch 12/100
# 3/3 [==============================] - 0s 58ms/step - loss: 1.6968 - categorical_accuracy: 0.8630 - val_loss: 2.0474 - val_categorical_accuracy: 0.7945
# Epoch 13/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6623 - categorical_accuracy: 0.8630 - val_loss: 2.0309 - val_categorical_accuracy: 0.7945
# Epoch 14/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.6259 - categorical_accuracy: 0.8630 - val_loss: 2.0471 - val_categorical_accuracy: 0.7945
# Epoch 15/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.5967 - categorical_accuracy: 0.8630 - val_loss: 2.0975 - val_categorical_accuracy: 0.7945
# Epoch 16/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.5401 - categorical_accuracy: 0.8630 - val_loss: 1.9629 - val_categorical_accuracy: 0.7945
# Epoch 17/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.4750 - categorical_accuracy: 0.8767 - val_loss: 2.1214 - val_categorical_accuracy: 0.7945
# Epoch 18/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.4399 - categorical_accuracy: 0.8870 - val_loss: 2.0472 - val_categorical_accuracy: 0.7808
# Epoch 19/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3847 - categorical_accuracy: 0.9075 - val_loss: 2.0953 - val_categorical_accuracy: 0.7808
# Epoch 20/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3476 - categorical_accuracy: 0.9247 - val_loss: 2.1620 - val_categorical_accuracy: 0.7808
# Epoch 21/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3068 - categorical_accuracy: 0.9075 - val_loss: 2.0667 - val_categorical_accuracy: 0.7534
# Epoch 22/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2591 - categorical_accuracy: 0.9486 - val_loss: 2.4997 - val_categorical_accuracy: 0.7945
# Epoch 23/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2834 - categorical_accuracy: 0.9110 - val_loss: 2.1334 - val_categorical_accuracy: 0.7671
# Epoch 24/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1911 - categorical_accuracy: 0.9692 - val_loss: 2.3780 - val_categorical_accuracy: 0.7808
# Epoch 25/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.1665 - categorical_accuracy: 0.9418 - val_loss: 2.1486 - val_categorical_accuracy: 0.7534
# Epoch 26/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1243 - categorical_accuracy: 0.9897 - val_loss: 2.4298 - val_categorical_accuracy: 0.7808
# Epoch 27/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.0996 - categorical_accuracy: 0.9795 - val_loss: 2.2957 - val_categorical_accuracy: 0.7808
# Epoch 28/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0662 - categorical_accuracy: 0.9966 - val_loss: 2.4666 - val_categorical_accuracy: 0.7808
# Epoch 29/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0433 - categorical_accuracy: 0.9966 - val_loss: 2.6359 - val_categorical_accuracy: 0.7671
# Epoch 30/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.0272 - categorical_accuracy: 0.9966 - val_loss: 2.5029 - val_categorical_accuracy: 0.7534
# Epoch 31/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0138 - categorical_accuracy: 1.0000 - val_loss: 2.5879 - val_categorical_accuracy: 0.7671
# Epoch 32/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9926 - categorical_accuracy: 1.0000 - val_loss: 2.8505 - val_categorical_accuracy: 0.7808
# Epoch 33/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9846 - categorical_accuracy: 1.0000 - val_loss: 2.6499 - val_categorical_accuracy: 0.7671
# Epoch 34/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.9741 - categorical_accuracy: 1.0000 - val_loss: 2.8726 - val_categorical_accuracy: 0.7671
# Epoch 35/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9642 - categorical_accuracy: 1.0000 - val_loss: 2.9897 - val_categorical_accuracy: 0.7808
# Epoch 36/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9511 - categorical_accuracy: 1.0000 - val_loss: 2.8825 - val_categorical_accuracy: 0.7397
# Epoch 37/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9448 - categorical_accuracy: 1.0000 - val_loss: 3.0114 - val_categorical_accuracy: 0.7671
# Epoch 38/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9346 - categorical_accuracy: 1.0000 - val_loss: 3.1667 - val_categorical_accuracy: 0.7808
# Epoch 39/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9268 - categorical_accuracy: 1.0000 - val_loss: 3.1247 - val_categorical_accuracy: 0.7671
# Epoch 40/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9187 - categorical_accuracy: 1.0000 - val_loss: 3.0861 - val_categorical_accuracy: 0.7671
# Epoch 41/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9108 - categorical_accuracy: 1.0000 - val_loss: 3.1198 - val_categorical_accuracy: 0.7671
# Epoch 42/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9031 - categorical_accuracy: 1.0000 - val_loss: 3.1750 - val_categorical_accuracy: 0.7808
# Epoch 43/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8960 - categorical_accuracy: 1.0000 - val_loss: 3.1539 - val_categorical_accuracy: 0.7808
# Epoch 44/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8886 - categorical_accuracy: 1.0000 - val_loss: 3.1038 - val_categorical_accuracy: 0.7671
# Epoch 45/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8815 - categorical_accuracy: 1.0000 - val_loss: 3.1125 - val_categorical_accuracy: 0.7671
# Epoch 46/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8746 - categorical_accuracy: 1.0000 - val_loss: 3.1706 - val_categorical_accuracy: 0.7671
# Epoch 47/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8677 - categorical_accuracy: 1.0000 - val_loss: 3.2071 - val_categorical_accuracy: 0.7671
# Epoch 48/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8609 - categorical_accuracy: 1.0000 - val_loss: 3.2098 - val_categorical_accuracy: 0.7671
# Epoch 49/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8541 - categorical_accuracy: 1.0000 - val_loss: 3.1662 - val_categorical_accuracy: 0.7534
# Epoch 50/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8475 - categorical_accuracy: 1.0000 - val_loss: 3.1599 - val_categorical_accuracy: 0.7534
# Epoch 51/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.8410 - categorical_accuracy: 1.0000 - val_loss: 3.2030 - val_categorical_accuracy: 0.7671
# Epoch 52/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8345 - categorical_accuracy: 1.0000 - val_loss: 3.2185 - val_categorical_accuracy: 0.7671
# Epoch 53/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8282 - categorical_accuracy: 1.0000 - val_loss: 3.2076 - val_categorical_accuracy: 0.7671
# Epoch 54/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8219 - categorical_accuracy: 1.0000 - val_loss: 3.1856 - val_categorical_accuracy: 0.7671
# Epoch 55/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8157 - categorical_accuracy: 1.0000 - val_loss: 3.1849 - val_categorical_accuracy: 0.7671
# Epoch 56/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8095 - categorical_accuracy: 1.0000 - val_loss: 3.2008 - val_categorical_accuracy: 0.7671
# Epoch 57/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8034 - categorical_accuracy: 1.0000 - val_loss: 3.2154 - val_categorical_accuracy: 0.7671
# Epoch 58/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7974 - categorical_accuracy: 1.0000 - val_loss: 3.1962 - val_categorical_accuracy: 0.7671
# Epoch 59/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7915 - categorical_accuracy: 1.0000 - val_loss: 3.1911 - val_categorical_accuracy: 0.7671
# Epoch 60/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7856 - categorical_accuracy: 1.0000 - val_loss: 3.1859 - val_categorical_accuracy: 0.7671
# Epoch 61/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7798 - categorical_accuracy: 1.0000 - val_loss: 3.1715 - val_categorical_accuracy: 0.7671
# Epoch 62/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7741 - categorical_accuracy: 1.0000 - val_loss: 3.1795 - val_categorical_accuracy: 0.7671
# Epoch 63/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7684 - categorical_accuracy: 1.0000 - val_loss: 3.1940 - val_categorical_accuracy: 0.7671
# Epoch 64/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7628 - categorical_accuracy: 1.0000 - val_loss: 3.1741 - val_categorical_accuracy: 0.7671
# Epoch 65/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7572 - categorical_accuracy: 1.0000 - val_loss: 3.1568 - val_categorical_accuracy: 0.7534
# Epoch 66/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7518 - categorical_accuracy: 1.0000 - val_loss: 3.1978 - val_categorical_accuracy: 0.7671
# Epoch 67/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7463 - categorical_accuracy: 1.0000 - val_loss: 3.2068 - val_categorical_accuracy: 0.7671
# Epoch 68/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7409 - categorical_accuracy: 1.0000 - val_loss: 3.1774 - val_categorical_accuracy: 0.7671
# Epoch 69/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7355 - categorical_accuracy: 1.0000 - val_loss: 3.1476 - val_categorical_accuracy: 0.7671
# Epoch 70/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7303 - categorical_accuracy: 1.0000 - val_loss: 3.1993 - val_categorical_accuracy: 0.7671
# Epoch 71/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7250 - categorical_accuracy: 1.0000 - val_loss: 3.1291 - val_categorical_accuracy: 0.7671
# Epoch 72/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7199 - categorical_accuracy: 1.0000 - val_loss: 3.1236 - val_categorical_accuracy: 0.7671
# Epoch 73/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7148 - categorical_accuracy: 1.0000 - val_loss: 3.1770 - val_categorical_accuracy: 0.7671
# Epoch 74/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7097 - categorical_accuracy: 1.0000 - val_loss: 3.1386 - val_categorical_accuracy: 0.7671
# Epoch 75/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7047 - categorical_accuracy: 1.0000 - val_loss: 3.1093 - val_categorical_accuracy: 0.7534
# Epoch 76/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6997 - categorical_accuracy: 1.0000 - val_loss: 3.1437 - val_categorical_accuracy: 0.7671
# Epoch 77/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.6947 - categorical_accuracy: 1.0000 - val_loss: 3.1765 - val_categorical_accuracy: 0.7671
# Epoch 78/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.6899 - categorical_accuracy: 1.0000 - val_loss: 3.1400 - val_categorical_accuracy: 0.7671
# Epoch 79/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6850 - categorical_accuracy: 1.0000 - val_loss: 3.0978 - val_categorical_accuracy: 0.7534
# Epoch 80/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6803 - categorical_accuracy: 1.0000 - val_loss: 3.1107 - val_categorical_accuracy: 0.7534
# Epoch 81/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6755 - categorical_accuracy: 1.0000 - val_loss: 3.1569 - val_categorical_accuracy: 0.7671
# Epoch 82/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6708 - categorical_accuracy: 1.0000 - val_loss: 3.1491 - val_categorical_accuracy: 0.7671
# Epoch 83/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6662 - categorical_accuracy: 1.0000 - val_loss: 3.1190 - val_categorical_accuracy: 0.7671
# Epoch 84/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6615 - categorical_accuracy: 1.0000 - val_loss: 3.1011 - val_categorical_accuracy: 0.7671
# Epoch 85/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6570 - categorical_accuracy: 1.0000 - val_loss: 3.1330 - val_categorical_accuracy: 0.7671
# Epoch 86/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6525 - categorical_accuracy: 1.0000 - val_loss: 3.1398 - val_categorical_accuracy: 0.7671
# Epoch 87/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.6480 - categorical_accuracy: 1.0000 - val_loss: 3.1001 - val_categorical_accuracy: 0.7534
# Epoch 88/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6435 - categorical_accuracy: 1.0000 - val_loss: 3.0889 - val_categorical_accuracy: 0.7671
# Epoch 89/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.6392 - categorical_accuracy: 1.0000 - val_loss: 3.1084 - val_categorical_accuracy: 0.7671
# Epoch 90/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6348 - categorical_accuracy: 1.0000 - val_loss: 3.0889 - val_categorical_accuracy: 0.7534
# Epoch 91/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.6305 - categorical_accuracy: 1.0000 - val_loss: 3.0903 - val_categorical_accuracy: 0.7534
# Epoch 92/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6262 - categorical_accuracy: 1.0000 - val_loss: 3.1108 - val_categorical_accuracy: 0.7671
# Epoch 93/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6220 - categorical_accuracy: 1.0000 - val_loss: 3.0977 - val_categorical_accuracy: 0.7671
# Epoch 94/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6177 - categorical_accuracy: 1.0000 - val_loss: 3.1032 - val_categorical_accuracy: 0.7534
# Epoch 95/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6136 - categorical_accuracy: 1.0000 - val_loss: 3.0892 - val_categorical_accuracy: 0.7534
# Epoch 96/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.6095 - categorical_accuracy: 1.0000 - val_loss: 3.0931 - val_categorical_accuracy: 0.7534
# Epoch 97/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6054 - categorical_accuracy: 1.0000 - val_loss: 3.0893 - val_categorical_accuracy: 0.7534
# Epoch 98/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6013 - categorical_accuracy: 1.0000 - val_loss: 3.0760 - val_categorical_accuracy: 0.7534
# Epoch 99/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5973 - categorical_accuracy: 1.0000 - val_loss: 3.1125 - val_categorical_accuracy: 0.7671
# Epoch 100/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5933 - categorical_accuracy: 1.0000 - val_loss: 3.1011 - val_categorical_accuracy: 0.7534
# 3/3 [==============================] - 0s 4ms/step
#    precision_macro  recall_macro  f1_macro  precision_weighted  \
# 0         0.156522           0.2   0.17561            0.612476
#
#    recall_weighted  f1_weighted  accuracy
# 0         0.782609     0.687169  0.782609
